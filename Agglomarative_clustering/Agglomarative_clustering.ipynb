# %% [markdown]
# <a href="https://colab.research.google.com/github/devikasinha/Unsupervised_Learning/blob/main/hierarical_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import numpy as np
import pandas as pd

np.random.seed(42)

data = np.random.rand(30, 3)

df = pd.DataFrame(data, columns=['Feature_A', 'Feature_B', 'Feature_C'])
print("Dataset Preview (First 5 rows):")
print(df.head())
# Out:
# Dataset Preview (First 5 rows):
#    Feature_A  Feature_B  Feature_C
# 0   0.374540   0.950714   0.731994
# 1   0.598658   0.156019   0.155995
# 2   0.058084   0.866176   0.601115
# 3   0.708073   0.020584   0.969910
# 4   0.832443   0.212339   0.181825

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
import numpy as np
plt.figure(figsize=(10, 7))
plt.title("Dendrogram for Hierarchical Clustering")

dendrogram = sch.dendrogram(sch.linkage(df, method='ward'))

plt.xlabel('Sample Index')
plt.ylabel('Euclidean Distances')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

hc = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')

y_hc = hc.fit_predict(df)

df['Cluster'] = y_hc

print("Data with Cluster Labels:")
print(df.head(10))
# Out:
# Data with Cluster Labels:
#    Feature_A  Feature_B  Feature_C  Cluster
# 0   0.374540   0.950714   0.731994        0
# 1   0.598658   0.156019   0.155995        2
# 2   0.058084   0.866176   0.601115        0
# 3   0.708073   0.020584   0.969910        1
# 4   0.832443   0.212339   0.181825        2
# 5   0.183405   0.304242   0.524756        1
# 6   0.431945   0.291229   0.611853        1
# 7   0.139494   0.292145   0.366362        1
# 8   0.456070   0.785176   0.199674        2
# 9   0.514234   0.592415   0.046450        2

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(df['Feature_A'], df['Feature_B'], df['Feature_C'],
                     c=df['Cluster'], s=100, cmap='viridis')

ax.set_title('Hierarchical Clustering Results (3D View)')
ax.set_xlabel('Feature A')
ax.set_ylabel('Feature B')
ax.set_zlabel('Feature C')
plt.colorbar(scatter, label='Cluster ID')

plt.show()
